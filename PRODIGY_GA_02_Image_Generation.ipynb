# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !pip install diffusers transformers accelerate safetensors
# !pip install torch torchvision

# %%
import torch
from diffusers import StableDiffusionPipeline
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]

# %%
prompt = "A breathtaking futuristic smart city at sunset, tall glass skyscrapers with glowing neon lights, numerous flying cars moving through the sky, elevated highways, holographic billboards, lush rooftop gardens, reflective buildings, cinematic lighting, ultra realistic, highly detailed, vibrant colors, 8k, masterpiece, digital art"

image = pipe(prompt).images[0]
image.save("image1.png")
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "A magical enchanted forest filled with giant glowing mushrooms, dragons, sparkling waterfalls, ancient trees covered with glowing vines, colorful butterflies, tiny fairies flying around, mystical atmosphere, golden sunlight passing through the trees, fantasy concept art, ultra detailed, vibrant colors, masterpiece, 8k"

image = pipe(prompt).images[0]
image.save("image2.png")
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "A realistic white horse galloping across the red desert of Mars, a NASA astronaut wearing a detailed white spacesuit riding the horse, dramatic rocky mountains in the background, Earth visible in the night sky, red dust flying behind the horse, cinematic lighting, ultra realistic, full body, highly detailed, photorealistic, 8k"

image = pipe(prompt).images[0]
image.save("image3.png")
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "A majestic floating castle above the clouds, connected by glowing waterfalls, flying dragons circling the towers, golden sunset, colorful sky, magical atmosphere, fantasy kingdom, ultra realistic, highly detailed, cinematic lighting, masterpiece, 8k"

image = pipe(prompt).images[0]
image.save("image4.png")
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import json

with open('/content/PRODIGY_GA_02_Image_Generation.ipynb', 'r') as f:
    nb = json.load(f)

if 'widgets' in nb.get('metadata', {}):
    del nb['metadata']['widgets']

with open('/content/PRODIGY_GA_02_Image_Generation.ipynb', 'w') as f:
    json.dump(nb, f)

print("✅ Fixed!")
# Out:
# ✅ Fixed!
